# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SpatialDataSet.txt')

# %%
df.head()
# Out:
#    longitude  latitude
# 0    55.8076      37.5
# 1    55.8077      37.5
# 2    55.8078      37.5
# 3    55.8079      37.5
# 4    55.8075      37.5

# %%
#df.axes?

# %%
BBox=(55.8075, 55.8124,37.4948,37.5040)

# %%
#BBox = (df.longitude.min(),   df.longitude.max(), df.latitude.min(), df.latitude.max())

# %%
#df.min?

# %% [markdown]
# ###> (55.8075, 55.8124,37.4948,37.5040)

# %%
MAI_map = plt.imread('MAI_map.png')

# %%
#df.longitude= [55.8075, 55.8124]

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.longitude, df.latitude, zorder=1, alpha= 0.5, c='g', s=100,marker='^')
ax.set_title('Plotting Spatial Data on Moscow MAI Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
ax.scatter?

# %%
matplotlib.markers?
# Out:
# Object `matplotlib.markers` not found.
